# %% [markdown]
# <a href="https://colab.research.google.com/github/kholiq19/TugasKholiq/blob/main/Histogram_kholiq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 200612
# Rafi Nurkholiq Ajiz
# Tugas HISTOGRAM

# %% [markdown]
# Import Gambar

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# BGR DAN RGB

# %%
#link image
url ="/content/drive/MyDrive/Pengolahan Citra Digital/Histogram/IMG_20220716_111052.jpg"

image = io.imread(url)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
final_frame = cv.hconcat((image, image_2))
cv2_imshow(final_frame)

# %% [markdown]
# Size Gambar

# %%
print(image.size)
print(image.shape)
print(image.dtype)
# Out:
# 22235892
# (2716, 2729, 3)
# uint8

# %% [markdown]
# Ploating Histogram

# %%
import numpy as np
a = np.array([[1,2,2,2,10],[10,20,30,40,50]])
print(a)
print(a.ravel())
print(a.flatten())
plt.hist(a.ravel(),bins = 50, range = [0,50])
plt.show()
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %%
plt.hist(image.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# Histogram BGR

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([image], [i], None, [256], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,256])
plt.show()

# %% [markdown]
# Split Channel

# %%
b,g,r = cv.split(image)
cv2_imshow(b)

# %% [markdown]
# Blue Channel

# %%
image = io.imread(url)

#blue channel
bluech = image[:,:,0]
cv2_imshow(bluech)

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='blue')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# Green Channel

# %%
#green channel
greench = image[:,:,1]
cv2_imshow(greench)

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# Red Channel

# %%
#red channel

redch = image[:,:,2]
cv2_imshow(redch)

# %%
plt.hist(redch.ravel(), 256, [0, 256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %% [markdown]
# Grayscale Histogram

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_image)

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 7411964
# (2716, 2729)
# uint8

# %% [markdown]
# IMAGE TRANSFORM-GRAYSCALE

# %% [markdown]
# Inverse Grayscale

# %%
invert_gray = 255 - gray_image
cv2_imshow(invert_gray)

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# High Brightness Image

# %%
bright_image = (100.0/255)*gray_image + 100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=2729x2716 at 0x7F24BBA9AD90>

# %%
plt.hist(bright_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %% [markdown]
# Darken Image Transform

# %%
darken_image = 255.0*(gray_image/255.0)**2
cv2_imshow(darken_image)

# %%
plt.hist(darken_image.ravel(), bins = 256, range = [0,256])
plt.show()
